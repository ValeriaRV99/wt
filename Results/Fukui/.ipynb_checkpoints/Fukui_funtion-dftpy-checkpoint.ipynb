# %%
import numpy as np
from ase import Atoms
from ase.build import bulk
from ase.visualize import view
from dftpy.grid import DirectGrid
from dftpy.field import DirectField
from dftpy.functional import Functional, TotalFunctional, FunctionalOutput
from dftpy.functional.abstract_functional import AbstractFunctional
from dftpy.ions import Ions
from dftpy.constants import Units
from dftpy.formats import io
from dftpy.mpi import mp
from ase.io import read
from dftpy.math_utils import ecut2nr
from dftpy.optimization import Optimization


path_pp='/Users/valeria/Documents/PP/ofpp/EAC/upf/blps/'
file='si.lda.upf'
PP_list = {'Si': path_pp+file}

# %%
import os
os.chdir('../..')
path_file = os.getcwd()

# %%
dictionary = {
    'Si_Btin': {'file': 'Si_Btin.vasp'}, 
    'Si_fcc': {'file': 'Si_fcc.vasp'},
    'Si_bcc': {'file': 'Si_bcc.vasp'},
    'Si_cd': {'file': 'Si_cd.vasp'},
    'Si_dhcp': {'file': 'Si_dhcp.vasp'},
    'Si_bct5': {'file': 'Si_bct5.vasp'},
    'Si_sh': {'file': 'Si_sh.vasp'},
    'Si_cbcc': {'file': 'Si_cbcc.vasp'},
    'Si_hcp': {'file': 'Si_hcp.vasp'},
}

def get_rho_ini(phase, charge):
    inputfile = path_file+'/Results/Structures/'+dictionary[phase]['file']
    ions = Ions.from_ase(read(inputfile, format='vasp'))
    nr = ecut2nr(ecut=25, lattice=ions.cell)
    grid = DirectGrid(lattice=ions.cell, nr=nr)
    if charge is None:
        pseudo = Functional(type='PSEUDO', grid = grid, ions=ions, PP_list=PP_list)
        rho_ini = DirectField(grid=grid)
        rho_ini[:] = ions.get_ncharges()/ions.cell.volume
    else:
        pseudo = Functional(type='PSEUDO', grid = grid, ions=ions, PP_list=PP_list)        
        rho_ini = DirectField(grid=grid)
        rho_ini[:] = (ions.get_ncharges()-charge)/ions.cell.volume
    return rho_ini, grid, pseudo, ions

# %%
Phases = ['Si_Btin', 'Si_fcc', 'Si_bcc', 'Si_cd', 'Si_dhcp', 'Si_hcp', 'Si_bct5', 'Si_sh']   

Rho_ini = []
Grid = []
Pseudo = []
IONS = []
for i,phase in enumerate(Phases):
    rho_ini, grid, pseudo, ions = get_rho_ini(phase, charge=None)
    Rho_ini.append(rho_ini)
    Grid.append(grid)
    Pseudo.append(pseudo)
    IONS.append(ions)

Rho_ini_charged = []
Grid_charged = []
Pseudo_charged = []
IONS_charged = []    
for i,phase in enumerate(Phases):
    rho_ini, grid, pseudo, ions = get_rho_ini(phase, charge=0.1)
    Rho_ini_charged.append(rho_ini)
    Grid_charged.append(grid)
    Pseudo_charged.append(pseudo)
    IONS_charged.append(ions)
# Out:
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# ...

# %%
xc = Functional(type='XC',name='LDA')
hartree = Functional(type='HARTREE')
rho0_KE_wt_cd = np.linspace(0.015,0.1,20)
rho_opt = []
ke_opt = []
# NEUTRAL
for i,phase in enumerate(Phases):
    for j in np.arange(0,20):
        ke = Functional(type='KEDF',name='WT', rho0= rho0_KE_wt_cd[j])
        evaluator = TotalFunctional(KE=ke, XC=xc, HARTREE=hartree, PSEUDO=Pseudo[i])
        optimization_options = {'econv' : 1e-7}
        opt = Optimization(EnergyEvaluator=evaluator, optimization_options = optimization_options,
                optimization_method = 'TN')

        Rho_opt = opt.optimize_rho(guess_rho=Rho_ini[i])
        rho_opt.append(Rho_opt)
        energy_opt = evaluator.Energy(rho=Rho_opt, ions=IONS[i])
        ke_opt = ke(Rho_opt).energy

rho_opt_charged = [] 
ke_opt_charged = []
# CHARGE
for i,phase in enumerate(Phases):
    for j in np.arange(0,20):
        ke = Functional(type='KEDF',name='WT', rho0= rho0_KE_wt_cd[j])
        evaluator = TotalFunctional(KE=ke, XC=xc, HARTREE=hartree, PSEUDO=Pseudo_charged[i])
        optimization_options = {'econv' : 1e-7}
        opt = Optimization(EnergyEvaluator=evaluator, optimization_options = optimization_options,
                optimization_method = 'TN')

        Rho_opt_charged = opt.optimize_rho(guess_rho=Rho_ini_charged[i])
        rho_opt_charged.append(Rho_opt_charged)
        energy_opt_charged = evaluator.Energy(rho=Rho_opt_charged, ions=IONS_charged[i])
        ke_opt_charged = ke(Rho_opt_charged).energy
# Out:
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -1.516417281674E+01     -1.516417E+01   2.736092E+00    1       1       3.098965E-03
# 1       -1.629437154921E+01     -1.130199E+00   1.617213E-01    11      2       3.132796E-02
# 2       -1.631621779191E+01     -2.184624E-02   1.361300E-02    8       1       4.243779E-02
# 3       -1.631768443691E+01     -1.466645E-03   1.287746E-03    7       1       5.225992E-02
# 4       -1.631790704495E+01     -2.226080E-04   4.727937E-05    10      1       6.696081E-02
# 5       -1.631791055620E+01     -3.511247E-06   3.072523E-06    5       1       7.446885E-02
# 6       -1.631791153147E+01     -9.752740E-07   2.195236E-07    11      2       9.187269E-02
# 7       -1.631791155181E+01     -2.033845E-08   1.115517E-08    6       1       1.015561E-01
# 8       -1.631791155367E+01     -1.860521E-09   7.054332E-10    9       1       1.152678E-01
# #### Density Optimization Converged ####
# ...

# %%
def fukui_fun(rho_n, rho_dn):
    return (rho_dn - rho_n)/0.1

# %%
fukui = []
# fukui_g = []
f_h = []
for i in np.arange(20*len(Phases)):
    fu = -fukui_fun(rho_opt[i], rho_opt_charged[i]) 
    print(fu.integral())
    fg = fu.fft()
    invg = fg.grid.gg
    mask = invg!=0
    invg[mask] = 1/invg[mask]
    fu_abs = np.sum((fg.imag**2+fg.real**2)*4*np.pi*invg)
    f = (fu_abs)
    f_h.append(f)
# Out:
# 0.9999999999996908
# 0.9999999999998028
# 0.9999999999998718
# 0.9999999999998084
# 0.9999999999999364
# 0.9999999999997905
# 0.999999999999897
# 0.9999999999997865
# 0.9999999999998977
# 0.9999999999999027
# 0.9999999999998525
# 0.9999999999998035
# 0.9999999999999416
# 0.9999999999999434
# 0.9999999999998875
# 0.9999999999999456
# 0.9999999999998889
# 0.9999999999998996
# 0.9999999999998929
# 0.9999999999998819
# 1.000000000000019
# 1.000000000000027
# 1.0000000000000253
# 1.000000000000038
# 1.0000000000000437
# 1.0000000000000446
# 0.9999999999999357
# 1.0000000000000249
# 1.0000000000000107
# 1.0000000000000753
# 0.9999999999999918
# 1.000000000000087
# 1.0000000000000153
# 0.9999999999999317
# 1.000000000000043
# 1.0000000000000409
# 1.0000000000000258
# 1.0000000000000149
# 0.9999999999999476
# 0.9999999999999959
# 1.0000000000000004
# 0.9999999999999625
# 1.0000000000000013
# 0.9999999999999765
# 0.9999999999999424
# 0.9999999999999909
# 0.999999999999962
# ...

# %%
# h = []
# hartree_potential = []
# for i in np.arange(20*len(Phases)):
#     h.append((hartree(fukui[i]).potential*f_h[i]).integral())
#     hartree_potential.append((hartree()))

# %%
# Phases = ['Si_Btin', 'Si_fcc', 'Si_bcc', 'Si_cd', 'Si_dhcp', 'Si_hcp', 'Si_bct5', 'Si_sh']  
# h_Btin = h[0:20]
# h_fcc = h[20:40]
# h_bcc = h[40:60]
# h_cd = h[60:80]

# %%
import h5py
file = h5py.File("/Users/valeria/Documents/aiWT/Model_ML_function/training_set_data/organize_data/Data_phases.hdf5", "r")
fileX = file["Descriptor"]
rho0_KE_WT = file["rho0_KE_wt"]
rho0_TE_WT = file["rho0_TE_wt"]
rho0_DEN_WT = file["rho0_DEN_wt"]
rho0_KE_SM = file["rho0_KE_sm"]
rho0_TE_SM = file["rho0_TE_sm"]
rho0_DEN_SM = file["rho0_DEN_sm"]
Rho = file["rho"]


rho0_KE_wt =[]
rho0_TE_wt =[]
rho0_DEN_wt=[]
rho0_KE_sm =[]
rho0_TE_sm =[]
rho0_DEN_sm =[]
rho = []
for i in np.arange(0,280):
    rho0_KE_wt.append(rho0_KE_WT[i][0]) 
    rho0_TE_wt.append(rho0_TE_WT[i][0]) 
    rho0_DEN_wt.append(rho0_DEN_WT[i][0])
    rho0_KE_sm.append(rho0_KE_SM[i][0]) 
    rho0_TE_sm.append(rho0_TE_SM[i][0]) 
    rho0_DEN_sm.append(rho0_DEN_SM[i][0])
    rho.append(Rho[i][0])

file.close()
rho0_Btin_KE_wt = rho0_KE_wt[0:30]
rho0_fcc_KE_wt = rho0_KE_wt[30:60]
rho0_bcc_KE_wt = rho0_KE_wt[60:90]
rho0_cd_KE_wt = rho0_KE_wt[90:120]
rho0_dhcp_KE_wt = rho0_KE_wt[120:150]
rho0_Btin_hd_KE_wt = rho0_KE_wt[150:180]
rho0_rand4_KE_wt = rho0_KE_wt[180:185]
rho0_rand8_KE_wt = rho0_KE_wt[185:190]
rho0_bct5_KE_wt = rho0_KE_wt[190:220]
rho0_hcp_KE_wt = rho0_KE_wt[220:250]
rho0_sh_KE_wt = rho0_KE_wt[250:280]

rho0_Btin_TE_wt = rho0_TE_wt[0:30]
rho0_fcc_TE_wt = rho0_TE_wt[30:60]
rho0_bcc_TE_wt = rho0_TE_wt[60:90]
rho0_cd_TE_wt = rho0_TE_wt[90:120]
rho0_dhcp_TE_wt = rho0_TE_wt[120:150]
rho0_Btin_hd_TE_wt = rho0_TE_wt[150:180]
rho0_rand4_TE_wt = rho0_TE_wt[180:185]
rho0_rand8_TE_wt = rho0_TE_wt[185:190]
rho0_bct5_TE_wt = rho0_TE_wt[190:220]
rho0_hcp_TE_wt = rho0_TE_wt[220:250]
rho0_sh_TE_wt = rho0_TE_wt[250:280]

rho0_Btin_DEN_wt = rho0_DEN_wt[0:30]
rho0_fcc_DEN_wt = rho0_DEN_wt[30:60]
rho0_bcc_DEN_wt = rho0_DEN_wt[60:90]
rho0_cd_DEN_wt = rho0_DEN_wt[90:120]
rho0_dhcp_DEN_wt = rho0_DEN_wt[120:150]
rho0_Btin_hd_DEN_wt = rho0_DEN_wt[150:180]
rho0_rand4_DEN_wt = rho0_DEN_wt[180:185]
rho0_rand8_DEN_wt = rho0_DEN_wt[185:190]
rho0_bct5_DEN_wt = rho0_DEN_wt[190:220]
rho0_hcp_DEN_wt = rho0_DEN_wt[220:250]
rho0_sh_DEN_wt = rho0_DEN_wt[250:280]

rho_Btin    = rho[0:30]
rho_fcc     = rho[30:60]
rho_bcc     = rho[60:90]
rho_cd      = rho[90:120]
rho_dhcp    = rho[120:150]
rho_Btin_hd = rho[150:180]
rho_rand4   = rho[180:185]
rho_rand8  = rho[185:190]
rho_bct5    = rho[190:220]
rho_hcp     = rho[220:250]
rho_sh      = rho[250:280]

rho = [rho_Btin[10], rho_fcc[10], rho_bcc[10], rho_cd[10]]

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, axs = plt.subplots(4,2, figsize=(12,12))
axs[0,0].scatter(rho0_KE_wt_cd, f_h[0:20])
axs[0,1].scatter(rho0_KE_wt_cd, f_h[20:40])
axs[1,0].scatter(rho0_KE_wt_cd, f_h[40:60])
axs[1,1].scatter(rho0_KE_wt_cd, f_h[60:80])
axs[2,0].scatter(rho0_KE_wt_cd, f_h[80:100])
axs[2,1].scatter(rho0_KE_wt_cd, f_h[100:120])
axs[3,0].scatter(rho0_KE_wt_cd, f_h[120:140])
axs[3,1].scatter(rho0_KE_wt_cd, f_h[140:160])
x_data = np.linspace(0.015,0.1,20)
rho_inter_Btin = np.interp(rho0_Btin_DEN_wt[10], x_data, f_h[0:20])
rho_interp_Btin = (rho0_Btin_DEN_wt[10], rho_inter_Btin)
te_inter_Btin = np.interp(rho0_Btin_TE_wt[10], x_data, f_h[0:20])
te_interp_Btin = (rho0_Btin_TE_wt[10], te_inter_Btin)
ke_inter_Btin = np.interp(rho0_Btin_KE_wt[10], x_data, f_h[0:20])
ke_interp_Btin = (rho0_Btin_KE_wt[10], ke_inter_Btin)
nv_inter_Btin = np.interp(rho[0], x_data, f_h[0:20])
nv_interp_Btin = (Rho_ini[0].mean(), nv_inter_Btin)

rho_inter_fcc = np.interp(rho0_fcc_DEN_wt[10], x_data, f_h[20:40])
rho_interp_fcc = (rho0_fcc_DEN_wt[10], rho_inter_fcc)
te_inter_fcc = np.interp(rho0_fcc_TE_wt[10], x_data, f_h[20:40])
te_interp_fcc = (rho0_fcc_TE_wt[10], te_inter_fcc)
ke_inter_fcc = np.interp(rho0_fcc_KE_wt[10], x_data, f_h[20:40])
ke_interp_fcc = (rho0_fcc_KE_wt[10], ke_inter_fcc)
nv_inter_fcc = np.interp(rho0_fcc_KE_wt[10], x_data, f_h[20:40])
nv_interp_fcc = (Rho_ini[1].mean(), nv_inter_fcc)

rho_inter_bcc = np.interp(rho0_bcc_DEN_wt[10], x_data, f_h[40:60])
rho_interp_bcc = (rho0_bcc_DEN_wt[10], rho_inter_bcc)
te_inter_bcc = np.interp(rho0_bcc_TE_wt[10], x_data, f_h[40:60])
te_interp_bcc = (rho0_bcc_TE_wt[10], te_inter_bcc)
ke_inter_bcc = np.interp(rho0_bcc_KE_wt[10], x_data, f_h[40:60])
ke_interp_bcc = (rho0_bcc_KE_wt[10], ke_inter_bcc)
nv_inter_bcc = np.interp(rho0_bcc_KE_wt[10], x_data, f_h[40:60])
nv_interp_bcc = (Rho_ini[2].mean(), nv_inter_bcc)

rho_inter_cd = np.interp(rho0_cd_DEN_wt[10], x_data, f_h[60:80])
rho_interp_cd = (rho0_cd_DEN_wt[10], rho_inter_cd)
te_inter_cd = np.interp(rho0_cd_TE_wt[10], x_data, f_h[60:80])
te_interp_cd = (rho0_cd_TE_wt[10], te_inter_cd)
ke_inter_cd = np.interp(rho0_cd_KE_wt[10], x_data, f_h[60:80])
ke_interp_cd = (rho0_cd_KE_wt[10], ke_inter_cd)
nv_inter_cd = np.interp(rho0_cd_KE_wt[10], x_data, f_h[60:80])
nv_interp_cd = (Rho_ini[3].mean(), nv_inter_cd)

rho_inter_dhcp = np.interp(rho0_dhcp_DEN_wt[10], x_data, f_h[80:100])
rho_interp_dhcp = (rho0_dhcp_DEN_wt[10], rho_inter_dhcp)
te_inter_dhcp = np.interp(rho0_dhcp_TE_wt[10], x_data, f_h[80:100])
te_interp_dhcp = (rho0_dhcp_TE_wt[10], te_inter_dhcp)
ke_inter_dhcp = np.interp(rho0_dhcp_KE_wt[10], x_data, f_h[80:100])
ke_interp_dhcp = (rho0_dhcp_KE_wt[10], ke_inter_dhcp)
nv_inter_dhcp = np.interp(rho0_dhcp_KE_wt[10], x_data, f_h[80:100])
nv_interp_dhcp = (Rho_ini[4].mean(), nv_inter_dhcp)

rho_inter_hcp = np.interp(rho0_hcp_DEN_wt[10], x_data, f_h[100:120])
rho_interp_hcp = (rho0_hcp_DEN_wt[10], rho_inter_hcp)
te_inter_hcp = np.interp(rho0_hcp_TE_wt[10], x_data, f_h[100:120])
te_interp_hcp = (rho0_hcp_TE_wt[10], te_inter_hcp)
ke_inter_hcp = np.interp(rho0_hcp_KE_wt[10], x_data, f_h[100:120])
ke_interp_hcp = (rho0_hcp_KE_wt[10], ke_inter_hcp)
nv_inter_hcp = np.interp(rho0_hcp_KE_wt[10], x_data, f_h[100:120])
nv_interp_hcp = (Rho_ini[5].mean(), nv_inter_hcp)

rho_inter_bct5 = np.interp(rho0_bct5_DEN_wt[10], x_data, f_h[120:140])
rho_interp_bct5 = (rho0_bct5_DEN_wt[10], rho_inter_bct5)
te_inter_bct5 = np.interp(rho0_bct5_TE_wt[10], x_data, f_h[120:140])
te_interp_bct5 = (rho0_bct5_TE_wt[10], te_inter_bct5)
ke_inter_bct5 = np.interp(rho0_bct5_KE_wt[10], x_data, f_h[120:140])
ke_interp_bct5 = (rho0_bct5_KE_wt[10], ke_inter_bct5)
nv_inter_bct5 = np.interp(rho0_bct5_KE_wt[10], x_data, f_h[120:140])
nv_interp_bct5 = (Rho_ini[6].mean(), nv_inter_bct5)

rho_inter_sh = np.interp(rho0_sh_DEN_wt[10], x_data, f_h[140:160])
rho_interp_sh = (rho0_sh_DEN_wt[10], rho_inter_sh)
te_inter_sh = np.interp(rho0_sh_TE_wt[10], x_data, f_h[140:160])
te_interp_sh = (rho0_sh_TE_wt[10], te_inter_sh)
ke_inter_sh = np.interp(rho0_sh_KE_wt[10], x_data, f_h[140:160])
ke_interp_sh = (rho0_sh_KE_wt[10], ke_inter_sh)
nv_inter_sh = np.interp(rho0_sh_KE_wt[10], x_data, f_h[140:160])
nv_interp_sh = (Rho_ini[3].mean(), nv_inter_sh)

axs[0,0].plot(x_data, f_h[0:20], label='TE response Btin')
axs[0,0].axvline(x=rho0_Btin_DEN_wt[10], color='r', linestyle='--', label='rho0 DEN')
axs[0,0].axvline(x=rho0_Btin_TE_wt[10], color='b', linestyle='--', label='rho0 TE')
axs[0,0].axvline(x=rho0_Btin_KE_wt[10], color='orange', linestyle='--', label='rho0 KE')
# axs[0,0].axhline(y=h_nv[0], color='magenta', linestyle='--', label='rho0 KE')
axs[0,0].axvline(x=Rho_ini[0].mean(), color='magenta', linestyle='--', label='N/V')
axs[0,0].scatter(*rho_interp_Btin, color='g', label='Intersection Point')

axs[0,1].plot(x_data, f_h[20:40], label='TE response fcc')
axs[0,1].axvline(x=rho0_fcc_DEN_wt[10], color='r', linestyle='--', label='rho0 DEN')
axs[0,1].axvline(x=rho0_fcc_TE_wt[10], color='b', linestyle='--', label='rho0 TE')
axs[0,1].axvline(x=rho0_fcc_KE_wt[10], color='orange', linestyle='--', label='rho0 KE')
# axs[0,1].axhline(y=h_nv[1], color='magenta', linestyle='--', label='N/V')
axs[0,1].axvline(x=Rho_ini[1].mean(), color='magenta', linestyle='--', label='N/V')

axs[0,1].scatter(*rho_interp_fcc, color='g', label='Intersection Point')


axs[1,0].plot(x_data, f_h[40:60], label='TE response bcc')
axs[1,0].axvline(x=rho0_bcc_DEN_wt[10], color='r', linestyle='--', label='rho0 DEN')
axs[1,0].axvline(x=rho0_bcc_TE_wt[10], color='b', linestyle='--', label='rho0 TE')
axs[1,0].axvline(x=rho0_bcc_KE_wt[10], color='orange', linestyle='--', label='rho0 KE')
# axs[1,0].axhline(y=h_nv[2], color='magenta', linestyle='--', label='N/V')
axs[1,0].axvline(x=Rho_ini[2].mean(), color='magenta', linestyle='--', label='N/V')
axs[1,0].scatter(*rho_interp_bcc, color='g', label='Intersection Point')

axs[1,1].plot(x_data, f_h[60:80], label='TE response cd')
axs[1,1].axvline(x=rho0_cd_DEN_wt[10], color='r', linestyle='--', label='rho0 DEN')
axs[1,1].axvline(x=rho0_cd_TE_wt[10], color='b', linestyle='--', label='rho0 TE')
axs[1,1].axvline(x=rho0_cd_KE_wt[10], color='orange', linestyle='--', label='rho0 KE')
# axs[1,1].axhline(y=h_nv[3], color='magenta', linestyle='--', label='N/V')
axs[1,1].axvline(x=Rho_ini[3].mean(), color='magenta', linestyle='--', label='N/V')
axs[1,1].scatter(*rho_interp_cd, color='g', label='Intersection Point')

axs[2,0].plot(x_data, f_h[80:100], label='TE response dhcp')
axs[2,0].axvline(x=rho0_dhcp_DEN_wt[10], color='r', linestyle='--', label='rho0 DEN')
axs[2,0].axvline(x=rho0_dhcp_TE_wt[10], color='b', linestyle='--', label='rho0 TE')
axs[2,0].axvline(x=rho0_dhcp_KE_wt[10], color='orange', linestyle='--', label='rho0 KE')
# axs[1,1].axhline(y=h_nv[3], color='magenta', linestyle='--', label='N/V')
axs[2,0].axvline(x=Rho_ini[3].mean(), color='magenta', linestyle='--', label='N/V')
axs[2,0].scatter(*rho_interp_dhcp, color='g', label='Intersection Point')

axs[2,1].plot(x_data, f_h[100:120], label='TE response hcp')
axs[2,1].axvline(x=rho0_hcp_DEN_wt[10], color='r', linestyle='--', label='rho0 DEN')
axs[2,1].axvline(x=rho0_hcp_TE_wt[10], color='b', linestyle='--', label='rho0 TE')
axs[2,1].axvline(x=rho0_hcp_KE_wt[10], color='orange', linestyle='--', label='rho0 KE')
# axs[1,1].axhline(y=h_nv[3], color='magenta', linestyle='--', label='N/V')
axs[2,1].axvline(x=Rho_ini[3].mean(), color='magenta', linestyle='--', label='N/V')
axs[2,1].scatter(*rho_interp_hcp, color='g', label='Intersection Point')

axs[3,0].plot(x_data, f_h[120:140], label='TE response bct5')
axs[3,0].axvline(x=rho0_bct5_DEN_wt[10], color='r', linestyle='--', label='rho0 DEN')
axs[3,0].axvline(x=rho0_bct5_TE_wt[10], color='b', linestyle='--', label='rho0 TE')
axs[3,0].axvline(x=rho0_bct5_KE_wt[10], color='orange', linestyle='--', label='rho0 KE')
# axs[1,1].axhline(y=h_nv[3], color='magenta', linestyle='--', label='N/V')
axs[3,0].axvline(x=Rho_ini[3].mean(), color='magenta', linestyle='--', label='N/V')
axs[3,0].scatter(*rho_interp_bct5, color='g', label='Intersection Point')

axs[3,1].plot(x_data, f_h[140:160], label='TE response sh')
axs[3,1].axvline(x=rho0_sh_DEN_wt[10], color='r', linestyle='--', label='rho0 DEN')
axs[3,1].axvline(x=rho0_sh_TE_wt[10], color='b', linestyle='--', label='rho0 TE')
axs[3,1].axvline(x=rho0_sh_KE_wt[10], color='orange', linestyle='--', label='rho0 KE')
# axs[1,1].axhline(y=h_nv[3], color='magenta', linestyle='--', label='N/V')
axs[3,1].axvline(x=Rho_ini[3].mean(), color='magenta', linestyle='--', label='N/V')
axs[3,1].scatter(*rho_interp_sh, color='g', label='Intersection Point')

axs[0,0].set_ylabel(r'Fukui')
axs[0,1].set_ylabel(r'Fukui')
axs[1,0].set_ylabel(r'Fukui')
axs[1,1].set_ylabel(r'Fukui')

axs[0,0].set_xlabel(r'$\rho_{0}$')
axs[0,1].set_xlabel(r'$\rho_{0}$')
axs[1,0].set_xlabel(r'$\rho_{0}$')
axs[1,1].set_xlabel(r'$\rho_{0}$')
axs[0,0].set_title(Phases[0])
axs[0,1].set_title(Phases[1])
axs[1,0].set_title(Phases[2])
axs[1,1].set_title(Phases[3])
plt.legend()

plt.show()

# %%
ks_fh = np.load('/Users/valeria/Documents/aiWT/Final_version/wt/Results/Fukui/Fukui_hartree.npy')

# %%
pwd
# Out:
# '/Users/valeria/Documents/aiWT/Final_version/wt'

# %%
Fukui_minus1.npy

# %%
from tabulate import tabulate
## Energies wrt KS bcc energies
data = [
    ["Btin", ke_interp_Btin[1], te_interp_Btin[1], rho_interp_Btin[1], nv_interp_Btin[1], ks_fh[0] ],
    ["bcc", ke_interp_bcc[1], te_interp_bcc[1], rho_interp_bcc[1], nv_interp_bcc[1], ks_fh[2] ],
    ["fcc", ke_interp_fcc[1], te_interp_fcc[1], rho_interp_fcc[1], nv_interp_fcc[1], ks_fh[1] ],
    ["hcp", ke_interp_hcp[1], te_interp_hcp[1], rho_interp_hcp[1], nv_interp_hcp[1], ks_fh[5] ],
    ["bct5", ke_interp_bct5[1], te_interp_bct5[1], rho_interp_bct5[1], nv_interp_bct5[1], ks_fh[6] ],
    ["sh", ke_interp_sh[1], te_interp_sh[1], rho_interp_sh[1], nv_interp_sh[1], ks_fh[7] ],
    ["cd", ke_interp_cd[1], te_interp_cd[1], rho_interp_cd[1], nv_interp_cd[1], ks_fh[3] ],
    ["dhcp", ke_interp_dhcp[1], te_interp_dhcp[1], rho_interp_dhcp[1], nv_interp_dhcp[1], ks_fh[4] ],
]

table = tabulate(data, headers=[r"Fukui function"," rho0_KIN"," rho0_TE"," rho0_DEN", " N/V", "KS"], tablefmt="grid")

# print(table)
print(tabulate(data, tablefmt="latex"))
# Out:
# \begin{tabular}{lrrrrr}
# \hline
#  Btin & 2.7506  & 3.01704  & 4.59887 & 3.852   & 5.32465   \\
#  bcc  & 3.03639 & 2.80193  & 3.37327 & 3.03639 & 0.123004  \\
#  fcc  & 2.29237 & 2.37943  & 1.88188 & 2.29237 & 0.0504051 \\
#  hcp  & 0.30271 & 0.451933 & 1.46194 & 0.30271 & 0.179051  \\
#  bct5 & 2.98188 & 3.00794  & 3.85417 & 2.98188 & 0.823554  \\
#  sh   & 4.05884 & 4.24512  & 5.144   & 4.05884 & 0.505964  \\
#  cd   & 3.86073 & 2.63934  & 2.73871 & 3.86073 & 3.63151   \\
#  dhcp & 3.55724 & 2.12134  & 3.56378 & 3.55724 & 4.43664   \\
# \hline
# \end{tabular}

# %%
\begin{tabular}{lrrrrr}
\hline
 Btin & 2.7506  & 3.01704  & 4.59887 & 3.852   & 2.66232   \\
 bcc  & 3.03639 & 2.80193  & 3.37327 & 3.03639 & 0.0615018 \\
 fcc  & 2.29237 & 2.37943  & 1.88188 & 2.29237 & 0.0252026 \\
 hcp  & 0.30271 & 0.451933 & 1.46194 & 0.30271 & 0.0895256 \\
 bct5 & 2.98188 & 3.00794  & 3.85417 & 2.98188 & 0.411777  \\
 sh   & 4.05885 & 4.24512  & 5.144   & 4.05885 & 0.252982  \\
 cd   & 3.86073 & 2.63934  & 2.73871 & 3.86073 & 1.81575   \\
 dhcp & 3.55724 & 2.12134  & 3.56378 & 3.55724 & 2.21832   \\
\hline
\end{tabular}
