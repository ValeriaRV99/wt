# %%
import numpy as np
from matplotlib import pyplot as plt

from dftpy.ions import Ions
from dftpy.field import DirectField
from dftpy.grid import DirectGrid
from dftpy.functional import LocalPseudo, Functional, TotalFunctional, ExternalPotential
from dftpy.formats import io
from dftpy.math_utils import ecut2nr
from dftpy.optimization import Optimization


from ase.build import bulk
from ase.io.trajectory import Trajectory
from ase.io import read
from ase.lattice.spacegroup import Spacegroup
from ase.lattice.spacegroup import crystal

from scipy.optimize import minimize
# Out:
# /opt/homebrew/lib/python3.11/site-packages/ase/lattice/spacegroup.py:5: UserWarning: Moved to ase.spacegroup
#   warnings.warn('Moved to ase.spacegroup')

# %%
import other_kedf

# %%
path_pp='/Users/valeria/Documents/PP/ofpp/EAC/upf/blps/'
file='si.lda.upf'
PP_list = {'Si': path_pp+file}

# %%
import os
os.chdir('../..')
path_file = os.getcwd()

# %%
pred_ke_Btin = []
pred_energy_Btin = []
r = np.linspace(0.8, 1.4, 30)
for i, d in enumerate(r): 
        ions = crystal('Si',[(0,0,0)],spacegroup=141,cellpar = [4.81,4.81,2.65, 90,90,90])
        cell = ions.get_cell()
        # ions.set_charges(4)
        ions.set_cell(cell * d, scale_atoms=True)
        vol = ions.get_volume()
        Wt_energy, Wt_ke, rho = other_kedf.get_energy(material=ions, KEDF='WT', a=None, b=None, PP_list=PP_list)
        rho.write(path_file+'/Results/Densities/Densities_WT/WT_rho0_Si_Btin_'+str(i)+'.xsf', ions=ions)
        pred_ke_Btin.append(Wt_ke)
        pred_energy_Btin.append(Wt_energy)
# Out:
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -1.451969576758E+01     -1.451970E+01   4.862715E+00    1       1       7.197857E-03
# 1       -1.553103131455E+01     -1.011336E+00   2.626187E-01    6       2       2.045417E-02
# 2       -1.554079602198E+01     -9.764707E-03   2.211141E-02    5       1       3.172183E-02
# 3       -1.554218429188E+01     -1.388270E-03   1.424655E-03    7       1       4.740810E-02
# 4       -1.554228843856E+01     -1.041467E-04   1.204488E-04    8       1       6.356907E-02
# 5       -1.554229557596E+01     -7.137408E-06   1.095399E-05    7       1       7.937717E-02
# 6       -1.554229652296E+01     -9.470018E-07   7.824195E-07    9       1       9.625387E-02
# #### Density Optimization Converged ####
# Chemical potential (a.u.): 0.7732512482997126
# Chemical potential (eV)  : 21.041238211307324
# ...

# %%
from ase import Atoms
import ase.io

pred_ke_bct5 = []
pred_energy_bct5 = []
r = np.linspace(0.8, 1.4, 30)
for i, d in enumerate(r): 
        inputfile = path_file+'/Results/Structures/Si_bct5.vasp'
        ions = ase.io.read(inputfile, format='vasp')
        cell = ions.get_cell()
        ions.set_cell(cell * d, scale_atoms=True)
        vol = ions.get_volume()
        Wt_energy, Wt_ke = other_kedf.get_energy(material=ions, KEDF='WT', a=None, b=None, PP_list=PP_list)
        rho.write(path_file+'/Results/Densities/Densities_WT/WT_rho0_Si_BCT5_'+str(i)+'.xsf', ions=ions)

        pred_ke_bct5.append(Wt_ke)
        pred_energy_bct5.append(Wt_energy)
# Out:
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -1.415672215522E+01     -1.415672E+01   4.853492E+00    1       1       6.065130E-03
# 1       -1.543847597091E+01     -1.281754E+00   3.243321E-01    8       2       2.346802E-02
# 2       -1.545152054284E+01     -1.304457E-02   2.833821E-02    5       1       3.683925E-02
# 3       -1.545350817168E+01     -1.987629E-03   2.688065E-03    7       1       5.256009E-02
# 4       -1.545361459760E+01     -1.064259E-04   2.275159E-04    7       1       6.865716E-02
# 5       -1.545363091475E+01     -1.631715E-05   1.505666E-05    9       1       8.671808E-02
# 6       -1.545363129353E+01     -3.787779E-07   1.420055E-06    3       1       9.961104E-02
# #### Density Optimization Converged ####
# Chemical potential (a.u.): 0.6804537342199013
# Chemical potential (eV)  : 18.516089233579926
# ...

# %%
pred_ke_fcc = []
pred_energy_fcc = []
r = np.linspace(0.8, 1.4, 30)
for i, d in enumerate(r): 
        ions = bulk('Si', 'fcc', a=3.405, cubic=True) 
        cell = ions.get_cell()
        ions.set_cell(cell * d, scale_atoms=True)
        vol = ions.get_volume()
        Wt_energy, Wt_ke = other_kedf.get_energy(material=ions, KEDF='WT', a=None, b=None, PP_list=PP_list)
        rho.write(path_file+'/Results/Densities/Densities_WT/WT_rho0_Si_fcc_'+str(i)+'.xsf', ions=ions)

        pred_ke_fcc.append(Wt_ke)
        pred_energy_fcc.append(Wt_energy)
# Out:
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -1.258763937401E+01     -1.258764E+01   8.744591E+00    1       1       4.963160E-03
# 1       -1.427781776104E+01     -1.690178E+00   5.564909E-01    3       2       1.270509E-02
# 2       -1.430781585710E+01     -2.999810E-02   3.700719E-02    5       1       1.913905E-02
# 3       -1.430978979575E+01     -1.973939E-03   1.318541E-03    7       1       2.728200E-02
# 4       -1.430983325771E+01     -4.346195E-05   7.671049E-05    5       1       3.574705E-02
# 5       -1.430983863875E+01     -5.381044E-06   4.586863E-06    7       1       4.827094E-02
# 6       -1.430983882724E+01     -1.884947E-07   3.885254E-07    4       1       5.588984E-02
# #### Density Optimization Converged ####
# Chemical potential (a.u.): 1.2164393742948671
# Chemical potential (eV)  : 33.101001389177384
# ...

# %%
pred_ke_8cd = []
pred_energy_8cd = []
r = np.linspace(0.8, 1.4, 30)
for i, d in enumerate(r): 
        ions = bulk('Si', 'diamond', a=5.43, cubic=True) 
        cell = ions.get_cell()
        ions.set_cell(cell * d, scale_atoms=True)
        vol = ions.get_volume()
        Wt_energy, Wt_ke, rho = other_kedf.get_energy(material=ions, KEDF='WT', a=None, b=None, PP_list=PP_list)
        rho.write(path_file+'/Results/Densities/Densities_WT/WT_rho0_Si_8cd_'+str(i)+'.xsf', ions=ions)

        pred_ke_8cd.append(Wt_ke)
        pred_energy_8cd.append(Wt_energy)
# Out:
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -2.757753886303E+01     -2.757754E+01   9.443993E+00    1       1       2.037406E-02
# 1       -3.078710038453E+01     -3.209562E+00   6.093228E-01    13      2       1.485729E-01
# 2       -3.081414927944E+01     -2.704889E-02   5.148869E-02    5       1       2.114120E-01
# 3       -3.081739043818E+01     -3.241159E-03   2.865395E-03    7       1       2.864981E-01
# 4       -3.081758169183E+01     -1.912537E-04   1.417838E-04    9       1       3.352787E-01
# 5       -3.081759019020E+01     -8.498376E-06   1.379807E-05    7       1       3.756580E-01
# 6       -3.081759140110E+01     -1.210897E-06   8.956775E-07    9       1       4.251971E-01
# #### Density Optimization Converged ####
# Chemical potential (a.u.): 0.544989207555313
# Chemical potential (eV)  : 14.829911705901623
# ...

# %%
pred_ke_bcc = []
pred_energy_bcc = []
r = np.linspace(0.8, 1.4, 30)
for i, d in enumerate(r): 
        ions = bulk('Si', 'bcc', a= 3.09, cubic=True) 
        cell = ions.get_cell()
        ions.set_cell(cell * d, scale_atoms=True)
        vol = ions.get_volume()
        Wt_energy, Wt_ke, rho = other_kedf.get_energy(material=ions, KEDF='WT', a=None, b=None, PP_list=PP_list)
        rho.write(path_file+'/Results/Densities/Densities_WT/WT_rho0_Si_bcc_'+str(i)+'.xsf', ions=ions)
        pred_ke_bcc.append(Wt_ke)
        pred_energy_bcc.append(Wt_energy)
# Out:
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -7.329735391929E+00     -7.329735E+00   2.532072E+00    1       1       3.511906E-03
# 1       -7.772244531115E+00     -4.425091E-01   2.071319E-01    2       1       7.319927E-03
# 2       -7.799383865522E+00     -2.713933E-02   1.688026E-02    6       1       1.353502E-02
# 3       -7.800128071984E+00     -7.442065E-04   1.548328E-03    4       1       1.812005E-02
# 4       -7.800264969048E+00     -1.368971E-04   9.734056E-05    6       1       2.421117E-02
# 5       -7.800270145693E+00     -5.176645E-06   5.677815E-06    5       1       3.035808E-02
# 6       -7.800270695746E+00     -5.500533E-07   3.452712E-07    7       1       3.915405E-02
# #### Density Optimization Converged ####
# Chemical potential (a.u.): 0.8192613566073444
# Chemical potential (eV)  : 22.29323702948924
# ...

# %%
pred_ke_sh = []
pred_energy_sh = []
r = np.linspace(0.8, 1.4, 30)
for i, d in enumerate(r): 
        inputfile = path_file+'/Results/Structures/Si_sh.vasp'
        ions = ase.io.read(inputfile, format='vasp')
        cell = ions.get_cell()
        ions.set_cell(cell * d, scale_atoms=True)
        vol = ions.get_volume()
        Wt_energy, Wt_ke, rho = other_kedf.get_energy(material=ions, KEDF='WT', a=None, b=None, PP_list=PP_list)
        rho.write(path_file+'/Results/Densities/Densities_WT/WT_rho0_Si_SH_'+str(i)+'.xsf', ions=ions)
        pred_ke_sh.append(Wt_ke)
        pred_energy_sh.append(Wt_energy)
# Out:
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -3.599836499241E+00     -3.599836E+00   1.285797E+00    1       1       3.483057E-03
# 1       -3.866341371956E+00     -2.665049E-01   9.372727E-02    6       2       1.031113E-02
# 2       -3.868977464063E+00     -2.636092E-03   6.451425E-03    6       1       1.536894E-02
# 3       -3.869376743904E+00     -3.992798E-04   3.572875E-04    9       1       2.481723E-02
# 4       -3.869407182755E+00     -3.043885E-05   2.786513E-05    11      1       3.596020E-02
# 5       -3.869408382836E+00     -1.200081E-06   2.234239E-06    8       1       4.270101E-02
# 6       -3.869408523971E+00     -1.411355E-07   1.513060E-07    10      1       5.249810E-02
# #### Density Optimization Converged ####
# Chemical potential (a.u.): 0.8101753314050412
# Chemical potential (eV)  : 22.045993690282238
# ...

# %%
pred_ke_dhcp = []
pred_energy_dhcp = []
r = np.linspace(0.8, 1.4, 30)
for i, d in enumerate(r): 
        inputfile = path_file+'/Results/Structures/Si_dhcp.vasp'
        ions = ase.io.read(inputfile, format='vasp')
        cell = ions.get_cell()
        ions.set_cell(cell * d, scale_atoms=True)
        vol = ions.get_volume()
        Wt_energy, Wt_ke, rho = other_kedf.get_energy(material=ions, KEDF='WT', a=None, b=None, PP_list=PP_list)
        rho.write(path_file+'/Results/Densities/Densities_WT/WT_rho0_Si_dhcp_'+str(i)+'.xsf', ions=ions)
        pred_ke_dhcp.append(Wt_ke)
        pred_energy_dhcp.append(Wt_energy)
# Out:
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -1.372653950328E+01     -1.372654E+01   4.839098E+00    1       1       6.110191E-03
# 1       -1.535224551067E+01     -1.625706E+00   6.595182E-01    13      2       3.921103E-02
# 2       -1.537291096795E+01     -2.066546E-02   4.764851E-02    6       1       5.680299E-02
# 3       -1.537621551714E+01     -3.304549E-03   2.379692E-03    10      1       8.343005E-02
# 4       -1.537635240999E+01     -1.368928E-04   1.775573E-04    10      1       1.090019E-01
# 5       -1.537636727361E+01     -1.486362E-05   9.426459E-06    13      1       1.398911E-01
# 6       -1.537636766126E+01     -3.876596E-07   7.126762E-07    7       1       1.570129E-01
# #### Density Optimization Converged ####
# Chemical potential (a.u.): 0.5567284154982959
# Chemical potential (eV)  : 15.149351824858448
# ...

# %%
pred_ke_hcp = []
pred_energy_hcp = []
r = np.linspace(0.8, 1.4, 30)
for i, d in enumerate(r): 
        inputfile = path_file+'/Results/Structures/Si_hcp.poscar'
        ions = ase.io.read(inputfile, format='vasp')
        cell = ions.get_cell()
        ions.set_cell(cell * d, scale_atoms=True)
        vol = ions.get_volume()
        Wt_energy, Wt_ke, rho = other_kedf.get_energy(material=ions, KEDF='WT', a=None, b=None, PP_list=PP_list)
        rho.write(path_file+'/Results/Densities/Densities_WT/WT_rho0_Si_HCP_'+str(i)+'.xsf', ions=ions)
        pred_ke_hcp.append(Wt_ke)
        pred_energy_hcp.append(Wt_energy)
# Out:
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -7.217825018655E+00     -7.217825E+00   2.760244E+00    1       1       3.537893E-03
# 1       -7.722695044130E+00     -5.048700E-01   2.308157E-01    3       1       8.334160E-03
# 2       -7.751159731374E+00     -2.846469E-02   2.316589E-02    9       1       1.848912E-02
# 3       -7.751884764609E+00     -7.250332E-04   1.795240E-03    6       1       2.787805E-02
# 4       -7.752006790780E+00     -1.220262E-04   1.517508E-04    9       1       3.940415E-02
# 5       -7.752013514845E+00     -6.724066E-06   1.265974E-05    8       1       5.060506E-02
# 6       -7.752014396685E+00     -8.818398E-07   1.263609E-06    10      1       6.193995E-02
# #### Density Optimization Converged ####
# Chemical potential (a.u.): 0.8698257129193031
# Chemical potential (eV)  : 23.6691632481676
# ...

# %%
pred_ke_cbcc = []
pred_energy_cbcc = []
r = np.linspace(0.8, 1.4, 30)
for i, d in enumerate(r): 
        inputfile = path_file+'/Results/Structures/Si_cbcc.vasp'
        ions = ase.io.read(inputfile, format='vasp')
        cell = ions.get_cell()
        ions.set_cell(cell * d, scale_atoms=True)
        vol = ions.get_volume()
        Wt_energy, Wt_ke, rho = other_kedf.get_energy(material=ions, KEDF='WT', a=None, b=None, PP_list=PP_list)
        rho.write(path_file+'/Results/Densities/Densities_WT/WT_rho0_Si_CBCC_'+str(i)+'.xsf', ions=ions)
        pred_ke_cbcc.append(Wt_ke)
        pred_energy_cbcc.append(Wt_energy)
# Out:
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -5.642789825224E+01     -5.642790E+01   1.865665E+01    1       1       1.703596E-02
# 1       -6.159378366296E+01     -5.165885E+00   1.188499E+00    10      2       1.413031E-01
# 2       -6.164076217584E+01     -4.697851E-02   1.126034E-01    5       1       2.229500E-01
# 3       -6.164904218476E+01     -8.280009E-03   6.886461E-03    8       1       3.008440E-01
# 4       -6.164948287318E+01     -4.406884E-04   4.853032E-04    9       1       3.494780E-01
# 5       -6.164950635643E+01     -2.348324E-05   3.471162E-05    7       1       3.886571E-01
# 6       -6.164951011800E+01     -3.761571E-06   1.997405E-06    10      1       4.413481E-01
# #### Density Optimization Converged ####
# Chemical potential (a.u.): 0.6497884260163591
# Chemical potential (eV)  : 17.681643694497144
# ...

# %%
# (path_file+'/Results/EOS/WT_results

np.save(path_file+'/Results/EOS/WT_results/WT_energy_Btin', pred_energy_Btin)
np.save(path_file+'/Results/EOS/WT_results/WT_energy_8cd',  pred_energy_8cd)
np.save(path_file+'/Results/EOS/WT_results/WT_energy_fcc',  pred_energy_fcc)
np.save(path_file+'/Results/EOS/WT_results/WT_energy_bct5', pred_energy_bct5)
np.save(path_file+'/Results/EOS/WT_results/WT_energy_fcc',  pred_energy_fcc)
np.save(path_file+'/Results/EOS/WT_results/WT_energy_bcc',  pred_energy_bcc)
np.save(path_file+'/Results/EOS/WT_results/WT_energy_hcp',  pred_energy_hcp)
np.save(path_file+'/Results/EOS/WT_results/WT_energy_cbcc', pred_energy_cbcc)
np.save(path_file+'/Results/EOS/WT_results/WT_energy_dhcp', pred_energy_dhcp)
np.save(path_file+'/Results/EOS/WT_results/WT_energy_sh',   pred_energy_sh)

np.save(path_file+'/Results/EOS/WT_results/WT_ke_Btin', pred_ke_Btin)
np.save(path_file+'/Results/EOS/WT_results/WT_ke_8cd',  pred_ke_8cd)
np.save(path_file+'/Results/EOS/WT_results/WT_ke_fcc',  pred_ke_fcc)
np.save(path_file+'/Results/EOS/WT_results/WT_ke_bct5', pred_ke_bct5)
np.save(path_file+'/Results/EOS/WT_results/WT_ke_fcc',  pred_ke_fcc)
np.save(path_file+'/Results/EOS/WT_results/WT_ke_bcc',  pred_ke_bcc)
np.save(path_file+'/Results/EOS/WT_results/WT_ke_hcp',  pred_ke_hcp)
np.save(path_file+'/Results/EOS/WT_results/WT_ke_cbcc', pred_ke_cbcc)
np.save(path_file+'/Results/EOS/WT_results/WT_ke_dhcp', pred_ke_dhcp)
np.save(path_file+'/Results/EOS/WT_results/WT_ke_sh',   pred_ke_sh)
