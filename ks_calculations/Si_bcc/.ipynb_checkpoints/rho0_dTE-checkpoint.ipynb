# %%
import numpy as np
from matplotlib import pyplot as plt

from dftpy.ions import Ions
from dftpy.functional import Functional
from dftpy.formats import io

from ase.io import read
from ase.lattice.spacegroup import Spacegroup
from ase.lattice.spacegroup import crystal
from ase.build import bulk
from scipy.optimize import minimize

from dftpy.ions import Ions
from dftpy.functional import Functional
from dftpy.formats import io
from dftpy.ions import Ions
from dftpy.field import DirectField
from dftpy.grid import DirectGrid
from dftpy.functional import LocalPseudo, Functional, TotalFunctional, ExternalPotential
from dftpy.formats import io
from dftpy.math_utils import ecut2nr
from dftpy.optimization import Optimization

# %%
path_pp='/Users/valeria/Documents/PP/ofpp/EAC/upf/blps/'
file='si.lda.upf'
PP_list = {'Si': path_pp+file}

# %%
KS_TE = []
for i in np.arange(0,30,1):
    with open('/Users/Valeria/Documents/aiWT/Model_ML_function/training_set_data/ks_calculations/Si_bcc/DATA2/Si'+str(i)+'.out') as D:
        k = [match for match in D if "!    total energy" in match]
    KS_te = str(k).split()[4]
    KS_TE.append(float(KS_te)) 
ks_te = np.asarray(KS_TE)

# %%
np.asarray(ks_te)
# Out:
# array([-15.63914145, -15.76099749, -15.85512309, -15.92676565,
#        -15.98016919, -16.01902663, -16.04624947, -16.06415338,
#        -16.07445694, -16.07853499, -16.07738451, -16.07173785,
#        -16.0622243 , -16.0496082 , -16.03474164, -16.01827806,
#        -16.0008434 , -15.98280957, -15.96430509, -15.94537049,
#        -15.92605109, -15.9063785 , -15.88639113, -15.86626566,
#        -15.84618638, -15.82631334, -15.80677468, -15.78761929,
#        -15.76884557, -15.75043351])

# %%
def min_energy(x0, *args):
        KS_TE, rho, ions = args
        KE = Functional(type='KEDF',name='WT', rho0=x0)
        grid = DirectGrid(lattice=ions.cell, nr=[len(rho),len(rho),len(rho[0,0])])
        PSEUDO = LocalPseudo(grid = grid, ions=ions, PP_list=PP_list, rcut=10)
        rho_ini = DirectField(grid=grid)
        rho_ini[:] = ions.get_ncharges()/ions.cell.volume
        
        evaluator = TotalFunctional(KE=KE, XC=XC, HARTREE=HARTREE, PSEUDO=PSEUDO)
        # optimization_options = {'econv' : 1e-5*ions.nat}
        # opt = Optimization(EnergyEvaluator=evaluator, optimization_options = optimization_options, 
        #                    optimization_method = 'TN')
        # rho = opt.optimize_rho(guess_rho=rho_ini)
        OF_TE = evaluator.Energy(rho=rho, ions=ions)
        # OF_KE = KE(rho).energy
        diff = np.abs(KS_TE*1/2-OF_TE)
        print(diff)
        return diff

# %%
XC = Functional(type='XC',name='LDA')
HARTREE = Functional(type='HARTREE')
l = np.linspace(0.8, 1.4, 30)
delta_E = []
R0 = []
vol = []
for n in np.arange(0,30,1):
    print("NEW STRUCTURE")
    i = int(n)
    rho = io.read_density('/Users/Valeria/Documents/aiWT/Model_ML_function/training_set_data/ks_calculations/Si_bcc/DATA2/rho0'+str(i)+'.xsf')
    ions = Ions.from_ase(bulk('Si', 'bcc', a= 3.09, cubic=True))    
    cell = ions.get_cell()
    ions.set_cell(cell * l[i], scale_atoms=True) 
    KS_TE = ks_te[i]
    minn = minimize(min_energy, 0.01, args = (KS_TE, rho, ions), method='Powell', bounds=[[0,10]], options={'ftol' : 1e-1})
    VOLUME = ions.get_volume()
    vol.append(VOLUME)
    delta_E.append(minn.fun)
    R0.append(minn.x)
# Out:
# NEW STRUCTURE
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.0034389852413134747
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.14328959265212227
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.14766198152194576
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.13728978356169907
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.12907735574510415
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.11790077890333706
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.10288397498243373
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.0829443837795969
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.05701810312492395
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# ...

# %%
fig, axs = plt.subplots(1,2, figsize=(10,3))
im0 = axs[0].plot(np.asarray(vol)*0.529177**3/4,np.asarray(delta_E)*1/4,'*--')
im1 = axs[1].plot(np.asarray(vol)*0.529177**3/4,np.asarray(R0),'*--')
axs[0].set_title('Si-\u03B2$_{tin}$')
axs[1].set_title('Si-\u03B2$_{tin}$')
axs[0].set_xlabel('Volume ($\AA^{3}$)')
axs[0].set_ylabel('$\Delta T_{s}$ (eV/atom)')
axs[1].set_xlabel('Volume ($\AA^{3}$)')
axs[1].set_ylabel('$\u03C1_{0}$')
# Out:
# Text(0, 0.5, '$ρ_{0}$')

# %%
R0
# Out:
# [array([0.06137295]),
#  array([0.05153203]),
#  array([0.07379512]),
#  array([0.07939137]),
#  array([0.08130619]),
#  array([0.08072802]),
#  array([0.05108159]),
#  array([0.0686216]),
#  array([0.06032082]),
#  array([0.05324931]),
#  array([0.04790261]),
#  array([0.04402909]),
#  array([0.04117439]),
#  array([0.03891838]),
#  array([0.03702484]),
#  array([0.03539876]),
#  array([0.033967]),
#  array([0.03268855]),
#  array([0.03154017]),
#  array([0.0305041]),
#  array([0.02956114]),
#  array([0.02869303]),
#  array([0.02789392]),
#  array([0.02715687]),
#  array([0.02646911]),
#  array([0.02582794]),
#  array([0.02522844]),
#  array([0.02466607]),
#  array([0.02413791]),
#  array([0.02364264])]

# %%
delta_E1 = []
R1 = []
vol1 = []
for n in np.arange(0,7,1):
    print("NEW STRUCTURE")
    i = int(n)
    rho = io.read_density('/Users/Valeria/Documents/aiWT/Model_ML_function/training_set_data/ks_calculations/Si_bcc/DATA2/rho0'+str(i)+'.xsf')
    ions = Ions.from_ase(bulk('Si', 'bcc', a= 3.09, cubic=True))    
    cell = ions.get_cell()
    ions.set_cell(cell * l[i], scale_atoms=True) 
    KS_TE = ks_te[i]
    minn = minimize(min_energy, 0.01, args = (KS_TE, rho, ions), method='Powell', bounds=[[0.069,0.09]], options={'ftol' : 1e-1})
    VOLUME = ions.get_volume()
    vol1.append(VOLUME)
    delta_E1.append(minn.fun)
    R1.append(minn.x)
# Out:
# NEW STRUCTURE
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# /var/folders/9b/gsh5m3sd3j96rq9k2zstrc_40000gn/T/ipykernel_10925/1507931312.py:12: OptimizeWarning: Initial guess is not within the specified bounds
#   minn = minimize(min_energy, 0.01, args = (KS_TE, rho, ions), method='Powell', bounds=[[0.069,0.09]], options={'ftol' : 1e-1})
# 0.0034389852413134747
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.0068422308051179215
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.0070583668268451305
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.005988337199086757
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.005321891997312811
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.004864666544572849
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# ...

# %%
rho0 = np.asarray(R0)
rho0[0:7] = np.asarray(R1)
d_E = np.asarray(delta_E)
d_E[0:7] = np.asarray(delta_E1)

# %%
fig, axs = plt.subplots(1,2, figsize=(10,3))
im0 = axs[0].plot(np.asarray(vol)*0.529177**3/4,np.asarray(d_E)*1/4,'*--')
im1 = axs[1].plot(np.asarray(vol)*0.529177**3/4,np.asarray(rho0),'*--')
axs[0].set_title('Si-\u03B2$_{tin}$')
axs[1].set_title('Si-\u03B2$_{tin}$')
axs[0].set_xlabel('Volume ($\AA^{3}$)')
axs[0].set_ylabel('$\Delta T_{s}$ (eV/atom)')
axs[1].set_xlabel('Volume ($\AA^{3}$)')
axs[1].set_ylabel('$\u03C1_{0}$')
# Out:
# Text(0, 0.5, '$ρ_{0}$')

# %%
rho0
# Out:
# array([[0.06906522],
#        [0.07814266],
#        [0.07379412],
#        [0.07937791],
#        [0.0813188 ],
#        [0.08071316],
#        [0.07630557],
#        [0.0686216 ],
#        [0.06032082],
#        [0.05324931],
#        [0.04790261],
#        [0.04402909],
#        [0.04117439],
#        [0.03891838],
#        [0.03702484],
#        [0.03539876],
#        [0.033967  ],
#        [0.03268855],
#        [0.03154017],
#        [0.0305041 ],
#        [0.02956114],
#        [0.02869303],
#        [0.02789392],
#        [0.02715687],
#        [0.02646911],
#        [0.02582794],
#        [0.02522844],
#        [0.02466607],
#        [0.02413791],
#        [0.02364264]])

# %%
delta_E2 = []
R2 = []
vol2 = []
for n in np.arange(0,5,1):
    print("NEW STRUCTURE")
    i = int(n)
    rho = io.read_density('/Users/Valeria/Documents/aiWT/Model_ML_function/training_set_data/ks_calculations/Si_bcc/DATA2/rho0'+str(i)+'.xsf')
    ions = Ions.from_ase(bulk('Si', 'bcc', a= 3.09, cubic=True))    
    cell = ions.get_cell()
    ions.set_cell(cell * l[i], scale_atoms=True) 
    KS_TE = ks_te[i]
    minn = minimize(min_energy, 0.01, args = (KS_TE, rho, ions), method='Powell', bounds=[[0.06,0.9]], options={'ftol' : 1e-1})
    VOLUME = ions.get_volume()
    vol2.append(VOLUME)
    delta_E2.append(minn.fun)
    R2.append(minn.x)
# Out:
# NEW STRUCTURE
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# /var/folders/9b/gsh5m3sd3j96rq9k2zstrc_40000gn/T/ipykernel_10925/3630270113.py:12: OptimizeWarning: Initial guess is not within the specified bounds
#   minn = minimize(min_energy, 0.01, args = (KS_TE, rho, ions), method='Powell', bounds=[[0.06,0.9]], options={'ftol' : 1e-1})
# 0.0034389852413134747
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.08760193363024005
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.1042472564565422
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.06811763103941271
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.047693695363983934
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.032027874634261266
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.01826014293385203
# ...

# %%
rho01 = np.asarray(rho0)
rho01[0:5] = np.asarray(R2)
d_E1 = np.asarray(d_E)
d_E1[0:5] = np.asarray(delta_E2)

# %%
fig, axs = plt.subplots(1,2, figsize=(10,3))
im0 = axs[0].plot(np.asarray(vol)*0.529177**3/4,np.asarray(d_E1)*1/4,'*--')
im1 = axs[1].plot(np.asarray(vol)*0.529177**3/4,np.asarray(rho01),'*--')
axs[0].set_title('Si-\u03B2$_{tin}$')
axs[1].set_title('Si-\u03B2$_{tin}$')
axs[0].set_xlabel('Volume ($\AA^{3}$)')
axs[0].set_ylabel('$\Delta T_{s}$ (eV/atom)')
axs[1].set_xlabel('Volume ($\AA^{3}$)')
axs[1].set_ylabel('$\u03C1_{0}$')
# Out:
# Text(0, 0.5, '$ρ_{0}$')

# %%
delta_E3 = []
R3 = []
vol3 = []
for n in np.arange(0,2,1):
    print("NEW STRUCTURE")
    i = int(n)
    rho = io.read_density('/Users/Valeria/Documents/aiWT/Model_ML_function/training_set_data/ks_calculations/Si_bcc/DATA2/rho0'+str(i)+'.xsf')
    ions = Ions.from_ase(bulk('Si', 'bcc', a= 3.09, cubic=True))    
    cell = ions.get_cell()
    ions.set_cell(cell * l[i], scale_atoms=True) 
    KS_TE = ks_te[i]
    minn = minimize(min_energy, 0.01, args = (KS_TE, rho, ions), method='Powell', bounds=[[0,0.075]], options={'ftol' : 1e-8})
    VOLUME = ions.get_volume()
    vol3.append(VOLUME)
    delta_E3.append(minn.fun)
    R3.append(minn.x)
# Out:
# NEW STRUCTURE
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.0034389852413134747
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.02065411532634176
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.011746679001460869
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.0026708074310048957
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.001576033195384241
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.0008745909691558751
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 4.240753155571042e-05
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.001004970354416379
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 5.799018670593625e-06
# ...

# %%
rho02 = np.asarray(rho01)
rho02[0:2] = np.asarray(R3)
d_E2 = np.asarray(d_E1)
d_E2[0:2] = np.asarray(delta_E3)

# %%
fig, axs = plt.subplots(1,2, figsize=(10,3))
im0 = axs[0].plot(np.asarray(vol)*0.529177**3/4,np.asarray(d_E2)*1/4,'*--')
im1 = axs[1].plot(np.asarray(vol)*0.529177**3/4,np.asarray(rho02),'*--')
axs[0].set_title('Si-bcc')
axs[1].set_title('Si-bcc')
axs[0].set_xlabel('Volume ($\AA^{3}$)')
axs[0].set_ylabel('$\Delta T_{s}$ (eV/atom)')
axs[1].set_xlabel('Volume ($\AA^{3}$)')
axs[1].set_ylabel('$\u03C1_{0}$')
# Out:
# Text(0, 0.5, '$ρ_{0}$')

# %%
delta_E4 = []
R4 = []
vol4 = []
for n in np.arange(0,1,1):
    print("NEW STRUCTURE")
    i = int(n)
    rho = io.read_density('/Users/Valeria/Documents/aiWT/Model_ML_function/training_set_data/ks_calculations/Si_bcc/DATA2/rho0'+str(i)+'.xsf')
    ions = Ions.from_ase(bulk('Si', 'bcc', a= 3.09, cubic=True))    
    cell = ions.get_cell()
    ions.set_cell(cell * l[i], scale_atoms=True) 
    KS_TE = ks_te[i]
    minn = minimize(min_energy, 0.01, args = (KS_TE, rho, ions), method='Powell', bounds=[[0,0.05]], options={'ftol' : 1e-8})
    VOLUME = ions.get_volume()
    vol4.append(VOLUME)
    delta_E4.append(minn.fun)
    R4.append(minn.x)
# Out:
# NEW STRUCTURE
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.0034389852413134747
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.009105294591959634
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.025331416141192165
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.004452355965193
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.001897781633067197
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.0003840847213236742
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.0006087527613374277
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 0.00014609739625548457
# setting key: Si -> /Users/valeria/Documents/PP/ofpp/EAC/upf/blps/si.lda.upf
# 3.229163423856818e-05
# ...

# %%
rho03 = np.asarray(rho02)
rho03[0:1] = np.asarray(R4)
d_E3 = np.asarray(d_E2)
d_E3[0:1] = np.asarray(delta_E4)

# %%
fig, axs = plt.subplots(1,2, figsize=(10,3))
im0 = axs[0].plot(np.asarray(vol)*0.529177**3/4,np.asarray(d_E3)*1/4,'*--')
im1 = axs[1].plot(np.asarray(vol)*0.529177**3/4,np.asarray(rho03),'*--')
axs[0].set_title('Si-bcc')
axs[1].set_title('Si-bcc')
axs[0].set_xlabel('Volume ($\AA^{3}$)')
axs[0].set_ylabel('$\Delta T_{s}$ (eV/atom)')
axs[1].set_xlabel('Volume ($\AA^{3}$)')
axs[1].set_ylabel('$\u03C1_{0}$')
# Out:
# Text(0, 0.5, '$ρ_{0}$')

# %%
np.save('/Users/Valeria/Documents/aiWT/Model_ML_function/training_set_data/ks_calculations/Si_bcc/DATA2/rho0_TE', np.asarray(rho03))

# %%
pip install jupyternotify
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for jupyternotify: filename=jupyternotify-0.1.15-py3-none-any.whl size=8723 sha256=7e869d169b4589941f597fe7db1708b85466c7f0c731704f1006f0a8983869b4
#   Stored in directory: /Users/valeria/Library/Caches/pip/wheels/ed/19/e2/59939d0f3bcf11547b07e9af34df315f836561f0c2f59acc6c
# Successfully built jupyternotify
# ...
# Note: you may need to restart the kernel to use updated packages.
